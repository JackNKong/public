# %%
import pandas as pd
df =pd.read_json('yahoo_finance_20210608.jl',lines=True)
df
# Out:
#     0y_date     1y_date     2y_date     3y_date     4y_date 0y_tot_revenue  \
# 0       ttm   9/30/2020   9/30/2019   9/30/2018   9/30/2017    325,406,000
# 1       ttm   6/30/2020   6/30/2019   6/30/2018   6/30/2017    159,969,000
# 2       ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017    196,682,000
# 3       ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017    196,682,000
# 4       ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017    419,130,000
# ..      ...         ...         ...         ...         ...            ...
# 183     ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017      8,573,000
# 184     ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017     27,841,000
# 185     ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017     38,859,059
# 186     ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017     46,817,000
# 187     ttm  12/31/2020  12/31/2019  12/31/2018  12/31/2017     12,890,000
#
# ...

# %%
df[['ticker','0y_tot_revenue','1y_tot_revenue','2y_tot_revenue','3y_tot_revenue','4y_tot_revenue','0y_oper_income','1y_oper_income','2y_oper_income','3y_oper_income','4y_oper_income'
    ,'0y_net_incom','1y_net_incom','2y_net_incom','3y_net_incom','4y_net_incom','0y_date','1y_date','2y_date','3y_date','4y_date']]
# Out:
#     ticker 0y_tot_revenue 1y_tot_revenue 2y_tot_revenue 3y_tot_revenue  \
# 0     AAPL    325,406,000    274,515,000    260,174,000    265,595,000
# 1     MSFT    159,969,000    143,015,000    125,843,000    110,360,000
# 2     GOOG    196,682,000    182,527,000    161,857,000    136,819,000
# 3    GOOGL    196,682,000    182,527,000    161,857,000    136,819,000
# 4     AMZN    419,130,000    386,064,000    280,522,000    232,887,000
# ..     ...            ...            ...            ...            ...
# 183   ATVI      8,573,000      8,086,000      6,489,000      7,500,000
# 184    COF     27,841,000     27,933,000     27,831,000     27,173,000
# 185   NTCO     38,859,059     36,921,980     14,444,690     13,397,419
# 186   EQNR     46,817,000     45,753,000     62,911,000     78,555,000
# 187    ITW     12,890,000     12,574,000     14,109,000     14,768,000
#
#     4y_tot_revenue 0y_oper_income 1y_oper_income 2y_oper_income  \
# ...
